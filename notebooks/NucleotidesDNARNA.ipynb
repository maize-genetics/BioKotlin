// %% [markdown]
// The `NUC` enum represents the full IUPAC encoding of DNA and RNA. Each
// constant carries the properties you would otherwise have to look up:
// molecular weights, complements, and ambiguity codes.

// %%
%use biokotlin
import biokotlin.seq.*

// Importing the enum constants lets you write `A` instead of `NUC.A`. Do this
// only when you are not also working with amino acids, whose single-letter
// names overlap.
import biokotlin.seq.NUC.*

// %% [markdown]
// The molecular weight of adenine as a DNA nucleotide:

// %%
A.dnaWeight

// %% [markdown]
// And its complement:

// %%
A.dnaComplement

// %% [markdown]
// Because `NUC` is an ordinary Kotlin enum, the whole standard collections
// framework applies. Here every nucleotide code is listed by weight.

// %%
NUC.values().asSequence()
    .sortedBy { it.rnaWeight }
    .forEach { println("$it weighs ${it.dnaWeight}") }
