// %% [markdown]
// ## This is our test tutorial!

// %%
@file:Repository("https://jcenter.bintray.com/")
@file:DependsOn("org.biokotlin:biokotlin:0.04")
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@d6467c1389bc031958acd5310fce39167b5cc581/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
// ...

// %% [markdown]
// Import the [seq](.seq) package!

// %%
import biokotlin.seq.*
import biokotlin.data.*
import biokotlin.seqIO.*

// %% [markdown]
// Create a sequence and output its [complement](.seq.NucSeq.complement).

// %%
val seq = NucSeq("GCAGAT") //DNA inferred because of "T"
seq.complement()

fun returnTypeTest(): Seq {
    return Seq("AG")
}

val madeFromConstructor = FastaIO("test", SeqType.protein)
val constant = biokotlin.data.standardCodonTable
// Out:
// Line_21.jupyter-kts (3:1 - 26) Property must be initialized or be abstract

// %% [markdown]
// This is the [Seq](.seq.Seq) class. This is the [Seq](.seq.Seq!) function
